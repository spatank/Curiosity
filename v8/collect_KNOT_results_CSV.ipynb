# %%
import scipy
import scipy.io as sio
from scipy.io import savemat
import pandas as pd
import numpy as np
import math

# %%
KNOT_all_raw = pd.read_csv('/Volumes/My Passport/Curiosity/Data/KNOT_data_raw.csv')
KNOT_all_raw.head(5)
# Out:
#     ID                      SourceName                      TargetName  Day  \
# 0  101                /wiki/Jeff_Bezos      /wiki/Cloud_infrastructure    1
# 1  101      /wiki/Cloud_infrastructure  /wiki/Cloud_computing_security    1
# 2  101  /wiki/Cloud_computing_security      /wiki/Cloud_infrastructure    1
# 3  101      /wiki/Cloud_infrastructure    /wiki/Information_technology    1
# 4  101    /wiki/Information_technology         /wiki/Computer_language    1
#
#    TimeOrder Hyperlink  DistanceWeights  AgeYears     SexOrient    Race  \
# 0          1        no              1.0  23.27945  Heterosexual  AsiaAm
# 1          2       yes              0.2  23.27945  Heterosexual  AsiaAm
# 2          3        no              0.2  23.27945  Heterosexual  AsiaAm
# 3          4       yes              0.8  23.27945  Heterosexual  AsiaAm
# 4          5        no              0.6  23.27945  Heterosexual  AsiaAm
#
#    GenderFactor     EducDeg   Income  JE_5D  DS_5D  ST_5D  SC_5D  TS_5D  \
# 0             0  BachDegree  20to49k    4.4   4.25    1.6    2.8    2.0
# 1             0  BachDegree  20to49k    4.4   4.25    1.6    2.8    2.0
# 2             0  BachDegree  20to49k    4.4   4.25    1.6    2.8    2.0
# 3             0  BachDegree  20to49k    4.4   4.25    1.6    2.8    2.0
# 4             0  BachDegree  20to49k    4.4   4.25    1.6    2.8    2.0
#
#    Count  Weight
# 0      1     0.0
# 1      2     0.8
# 2      3     0.8
# 3      4     0.2
# 4      5     0.4

# %%
reinf_reg = pd.read_csv('/Volumes/My Passport/Curiosity/Data/KNOT_reinf_reg.csv')
reinf_reg.head(5)
# Out:
#     ID  Reinforcement  Regularity
# 0  101      50.086906    2.095558
# 1  104      36.527710    1.871805
# 2  105      39.451567    1.932047
# 3  106      46.694123    2.089505
# 4  107      36.949026    2.308878

# %%
mat_contents = sio.loadmat('/Volumes/My Passport/Curiosity/v8/Data/KNOT/processed_KNOT_data.mat')
ID = mat_contents['ID']
density = mat_contents['density']
num_nodes = mat_contents['num_nodes']
num_edges = mat_contents['num_edges']
all_C = mat_contents['all_C']
all_d = mat_contents['all_d'] # embedding dimensionality curves
num_change_points = mat_contents['num_change_points'] # number of dimensionality increments
all_DoF_C = mat_contents['all_DoF_C'] # conformational degrees of freedom curves
all_Betti_0 = mat_contents['all_Betti_0'] # dimension 0 Betti curves
all_Betti_1 = mat_contents['all_Betti_1'] # dimension 1 Betti curves
all_Betti_2 = mat_contents['all_Betti_2'] # dimension 2 Betti curves

# %%
df = pd.DataFrame(columns = ['ID', 'Node', 'density', 'num_nodes', 'num_edges',
                             'C', 'd', 'num_change_points', 'DoF_C', 'Betti_0', 'Betti_1', 'Betti_2',
                             'Age', 'Sex', 'Race', 'Gender', 'Education', 'Income',
                             'JE', 'DS', 'ST', 'SC', 'TS',
                             'Regularity', 'Reinforcement'
                            ])
for i, subj_ID in enumerate(np.squeeze(ID).tolist()):
    print('Processing subject %d.' % subj_ID)
    subj_C = all_C[i, :]
    subj_d = all_d[i, :]
    subj_DoF_C = all_DoF_C[i, :]
    subj_Betti_0 = all_Betti_0[i, :]
    subj_Betti_1 = all_Betti_1[i, :]
    subj_Betti_2 = all_Betti_2[i, :]
    for j in range(subj_C.shape[0]):
        # if no data exists for a given filtration index, the network's size must be less than the max size.
        if (math.isnan(subj_C[j]) and math.isnan(subj_d[j]) and math.isnan(subj_DoF_C[j]) 
        and math.isnan(subj_Betti_0[j]) and math.isnan(subj_Betti_1[j]) and math.isnan(subj_Betti_2[j])):
            continue
        df = df.append({'ID': int(subj_ID), 
                        'Node': int(j + 1),  
                        'density': density[i][0], 
                        'num_nodes': num_nodes[i][0], 
                        'num_edges': num_edges[i][0], 
                        'C': subj_C[j],
                        'd': subj_d[j],
                        'num_change_points': num_change_points[i][0],
                        'DoF_C': subj_DoF_C[j],
                        'Betti_0': subj_Betti_0[j], 
                        'Betti_1': subj_Betti_1[j],
                        'Betti_2': subj_Betti_2[j],
                        'Age': KNOT_all_raw.loc[KNOT_all_raw['ID'] == subj_ID, 'AgeYears'].iloc[0],
                        'Sex': KNOT_all_raw.loc[KNOT_all_raw['ID'] == subj_ID, 'SexOrient'].iloc[0],
                        'Race': KNOT_all_raw.loc[KNOT_all_raw['ID'] == subj_ID, 'Race'].iloc[0],
                        'Gender': KNOT_all_raw.loc[KNOT_all_raw['ID'] == subj_ID, 'GenderFactor'].iloc[0],
                        'Education': KNOT_all_raw.loc[KNOT_all_raw['ID'] == subj_ID, 'EducDeg'].iloc[0],
                        'Income': KNOT_all_raw.loc[KNOT_all_raw['ID'] == subj_ID, 'Income'].iloc[0],
                        'JE': KNOT_all_raw.loc[KNOT_all_raw['ID'] == subj_ID, 'JE_5D'].iloc[0],
                        'DS': KNOT_all_raw.loc[KNOT_all_raw['ID'] == subj_ID, 'DS_5D'].iloc[0],
                        'ST': KNOT_all_raw.loc[KNOT_all_raw['ID'] == subj_ID, 'ST_5D'].iloc[0],
                        'SC': KNOT_all_raw.loc[KNOT_all_raw['ID'] == subj_ID, 'SC_5D'].iloc[0],
                        'TS': KNOT_all_raw.loc[KNOT_all_raw['ID'] == subj_ID, 'TS_5D'].iloc[0],
                        'Regularity': reinf_reg.loc[reinf_reg['ID'] == subj_ID, 'Regularity'].item(),
                        'Reinforcement': reinf_reg.loc[reinf_reg['ID'] == subj_ID, 'Reinforcement'].item()
                       }, ignore_index = True)
# Out:
# Processing subject 101.
# Processing subject 104.
# Processing subject 105.
# Processing subject 106.
# Processing subject 107.
# Processing subject 108.
# Processing subject 109.
# Processing subject 112.
# Processing subject 114.
# Processing subject 115.
# Processing subject 117.
# Processing subject 119.
# Processing subject 120.
# Processing subject 121.
# Processing subject 122.
# Processing subject 126.
# Processing subject 127.
# Processing subject 128.
# Processing subject 130.
# Processing subject 131.
# Processing subject 132.
# Processing subject 135.
# Processing subject 138.
# Processing subject 139.
# Processing subject 140.
# Processing subject 141.
# Processing subject 146.
# Processing subject 150.
# Processing subject 153.
# Processing subject 154.
# Processing subject 155.
# Processing subject 156.
# Processing subject 157.
# Processing subject 158.
# Processing subject 159.
# Processing subject 162.
# Processing subject 164.
# Processing subject 165.
# Processing subject 167.
# Processing subject 169.
# Processing subject 171.
# Processing subject 173.
# Processing subject 174.
# Processing subject 176.
# Processing subject 177.
# Processing subject 179.
# Processing subject 183.
# Processing subject 185.
# Processing subject 188.
# Processing subject 189.
# Processing subject 190.
# Processing subject 191.
# Processing subject 192.
# Processing subject 194.
# Processing subject 196.
# Processing subject 197.
# Processing subject 198.
# Processing subject 199.
# Processing subject 201.
# Processing subject 204.
# Processing subject 206.
# Processing subject 207.
# Processing subject 208.
# Processing subject 209.
# Processing subject 210.
# Processing subject 211.
# Processing subject 212.
# Processing subject 214.
# Processing subject 216.
# Processing subject 217.
# Processing subject 219.
# Processing subject 220.
# Processing subject 221.
# Processing subject 223.
# Processing subject 224.
# Processing subject 225.
# Processing subject 226.
# Processing subject 228.
# Processing subject 229.
# Processing subject 231.
# Processing subject 232.
# Processing subject 234.
# Processing subject 235.
# Processing subject 236.
# Processing subject 238.
# Processing subject 239.
# Processing subject 240.
# Processing subject 242.
# Processing subject 243.
# Processing subject 246.
# Processing subject 247.
# Processing subject 248.
# Processing subject 249.
# Processing subject 251.
# Processing subject 253.
# Processing subject 255.
# Processing subject 256.
# Processing subject 258.
# Processing subject 259.
# Processing subject 261.
# Processing subject 263.
# Processing subject 264.
# Processing subject 266.
# Processing subject 267.
# Processing subject 268.
# Processing subject 269.
# Processing subject 271.
# Processing subject 273.
# Processing subject 278.
# Processing subject 280.
# Processing subject 286.
# Processing subject 287.
# Processing subject 288.
# Processing subject 290.
# Processing subject 291.
# Processing subject 293.
# Processing subject 296.
# Processing subject 297.
# Processing subject 304.
# Processing subject 308.
# Processing subject 309.
# Processing subject 310.
# Processing subject 311.
# Processing subject 312.
# Processing subject 313.
# Processing subject 316.
# Processing subject 318.
# Processing subject 319.
# Processing subject 321.
# Processing subject 322.
# Processing subject 323.
# Processing subject 324.
# Processing subject 325.
# Processing subject 327.
# Processing subject 328.
# Processing subject 329.
# Processing subject 335.
# Processing subject 338.
# Processing subject 339.
# Processing subject 340340.
# Processing subject 340.
# Processing subject 342.
# Processing subject 349.
# Processing subject 351.
# Processing subject 353.
# Processing subject 355.
# Processing subject 356.
# Processing subject 359.
# Processing subject 363.

# %%
df.head(50)
# Out:
#      ID Node  density num_nodes num_edges         C    d num_change_points  \
# 0   101    1  0.01065       285       431       NaN  NaN                 1
# 1   101    2  0.01065       285       431       NaN  NaN                 1
# 2   101    3  0.01065       285       431       NaN  NaN                 1
# 3   101    4  0.01065       285       431       NaN  NaN                 1
# 4   101    5  0.01065       285       431       NaN  NaN                 1
# 5   101    6  0.01065       285       431       NaN  1.0                 1
# 6   101    7  0.01065       285       431  0.666667  1.0                 1
# 7   101    8  0.01065       285       431  0.577820  1.0                 1
# 8   101    9  0.01065       285       431  0.438752  2.0                 1
# 9   101   10  0.01065       285       431  0.415203  2.0                 1
# 10  101   11  0.01065       285       431  0.412416  2.0                 1
# 11  101   12  0.01065       285       431  0.398388  2.0                 1
# 12  101   13  0.01065       285       431  0.411763  2.0                 1
# 13  101   14  0.01065       285       431  0.411763  2.0                 1
# 14  101   15  0.01065       285       431  0.411763  2.0                 1
# 15  101   16  0.01065       285       431  0.509803  2.0                 1
# 16  101   17  0.01065       285       431  0.498837  2.0                 1
# 17  101   18  0.01065       285       431  0.489015  2.0                 1
# 18  101   19  0.01065       285       431  0.489015  2.0                 1
# 19  101   20  0.01065       285       431  0.489015  2.0                 1
# 20  101   21  0.01065       285       431  0.489015  2.0                 1
# 21  101   22  0.01065       285       431  0.480611  2.0                 1
# 22  101   23  0.01065       285       431  0.509190  2.0                 1
# 23  101   24  0.01065       285       431  0.509190  2.0                 1
# 24  101   25  0.01065       285       431  0.496005  2.0                 1
# 25  101   26  0.01065       285       431  0.456181  2.0                 1
# 26  101   27  0.01065       285       431  0.453822  2.0                 1
# 27  101   28  0.01065       285       431  0.453822  2.0                 1
# 28  101   29  0.01065       285       431  0.489650  2.0                 1
# 29  101   30  0.01065       285       431  0.480446  2.0                 1
# 30  101   31  0.01065       285       431  0.527045  2.0                 1
# 31  101   32  0.01065       285       431  0.524333  2.0                 1
# 32  101   33  0.01065       285       431  0.524333  2.0                 1
# 33  101   34  0.01065       285       431  0.553184  2.0                 1
# 34  101   35  0.01065       285       431  0.553184  2.0                 1
# 35  101   36  0.01065       285       431  0.576346  2.0                 1
# 36  101   37  0.01065       285       431  0.576530  2.0                 1
# 37  101   38  0.01065       285       431  0.570788  2.0                 1
# 38  101   39  0.01065       285       431  0.574253  2.0                 1
# 39  101   40  0.01065       285       431  0.591071  2.0                 1
# 40  101   41  0.01065       285       431  0.545186  2.0                 1
# 41  101   42  0.01065       285       431  0.540619  2.0                 1
# 42  101   43  0.01065       285       431  0.538716  2.0                 1
# 43  101   44  0.01065       285       431  0.538716  2.0                 1
# 44  101   45  0.01065       285       431  0.538716  2.0                 1
# 45  101   46  0.01065       285       431  0.538716  2.0                 1
# 46  101   47  0.01065       285       431  0.538716  2.0                 1
# 47  101   48  0.01065       285       431  0.538716  2.0                 1
# 48  101   49  0.01065       285       431  0.565349  2.0                 1
# 49  101   50  0.01065       285       431  0.565349  2.0                 1
#
#     DoF_C  Betti_0  ...  Gender   Education   Income   JE    DS   ST   SC  \
# 0     NaN      0.0  ...       0  BachDegree  20to49k  4.4  4.25  1.6  2.8
# 1     NaN      1.0  ...       0  BachDegree  20to49k  4.4  4.25  1.6  2.8
# 2     NaN      2.0  ...       0  BachDegree  20to49k  4.4  4.25  1.6  2.8
# 3     NaN      3.0  ...       0  BachDegree  20to49k  4.4  4.25  1.6  2.8
# 4     NaN      4.0  ...       0  BachDegree  20to49k  4.4  4.25  1.6  2.8
# 5     0.0      5.0  ...       0  BachDegree  20to49k  4.4  4.25  1.6  2.8
# 6     0.0      5.0  ...       0  BachDegree  20to49k  4.4  4.25  1.6  2.8
# 7     0.0      5.0  ...       0  BachDegree  20to49k  4.4  4.25  1.6  2.8
# 8     2.0      5.0  ...       0  BachDegree  20to49k  4.4  4.25  1.6  2.8
# 9     3.0      5.0  ...       0  BachDegree  20to49k  4.4  4.25  1.6  2.8
# 10    4.0      5.0  ...       0  BachDegree  20to49k  4.4  4.25  1.6  2.8
# 11    3.0      5.0  ...       0  BachDegree  20to49k  4.4  4.25  1.6  2.8
# 12    5.0      5.0  ...       0  BachDegree  20to49k  4.4  4.25  1.6  2.8
# 13    5.0      5.0  ...       0  BachDegree  20to49k  4.4  4.25  1.6  2.8
# 14    5.0      5.0  ...       0  BachDegree  20to49k  4.4  4.25  1.6  2.8
# 15    8.0      6.0  ...       0  BachDegree  20to49k  4.4  4.25  1.6  2.8
# 16    9.0      6.0  ...       0  BachDegree  20to49k  4.4  4.25  1.6  2.8
# 17   10.0      6.0  ...       0  BachDegree  20to49k  4.4  4.25  1.6  2.8
# 18   10.0      6.0  ...       0  BachDegree  20to49k  4.4  4.25  1.6  2.8
# 19   10.0      7.0  ...       0  BachDegree  20to49k  4.4  4.25  1.6  2.8
# 20   10.0      8.0  ...       0  BachDegree  20to49k  4.4  4.25  1.6  2.8
# 21   11.0      9.0  ...       0  BachDegree  20to49k  4.4  4.25  1.6  2.8
# 22   11.0      9.0  ...       0  BachDegree  20to49k  4.4  4.25  1.6  2.8
# 23   11.0      9.0  ...       0  BachDegree  20to49k  4.4  4.25  1.6  2.8
# 24   13.0     10.0  ...       0  BachDegree  20to49k  4.4  4.25  1.6  2.8
# 25   13.0     10.0  ...       0  BachDegree  20to49k  4.4  4.25  1.6  2.8
# 26   14.0      9.0  ...       0  BachDegree  20to49k  4.4  4.25  1.6  2.8
# 27   14.0      9.0  ...       0  BachDegree  20to49k  4.4  4.25  1.6  2.8
# 28   17.0     10.0  ...       0  BachDegree  20to49k  4.4  4.25  1.6  2.8
# 29   18.0     10.0  ...       0  BachDegree  20to49k  4.4  4.25  1.6  2.8
# 30   17.0     10.0  ...       0  BachDegree  20to49k  4.4  4.25  1.6  2.8
# 31   18.0     10.0  ...       0  BachDegree  20to49k  4.4  4.25  1.6  2.8
# 32   18.0     10.0  ...       0  BachDegree  20to49k  4.4  4.25  1.6  2.8
# 33   21.0     11.0  ...       0  BachDegree  20to49k  4.4  4.25  1.6  2.8
# 34   21.0     11.0  ...       0  BachDegree  20to49k  4.4  4.25  1.6  2.8
# 35   24.0     12.0  ...       0  BachDegree  20to49k  4.4  4.25  1.6  2.8
# 36   25.0     12.0  ...       0  BachDegree  20to49k  4.4  4.25  1.6  2.8
# 37   25.0     12.0  ...       0  BachDegree  20to49k  4.4  4.25  1.6  2.8
# 38   25.0     12.0  ...       0  BachDegree  20to49k  4.4  4.25  1.6  2.8
# 39   28.0     13.0  ...       0  BachDegree  20to49k  4.4  4.25  1.6  2.8
# 40   27.0     13.0  ...       0  BachDegree  20to49k  4.4  4.25  1.6  2.8
# 41   28.0     13.0  ...       0  BachDegree  20to49k  4.4  4.25  1.6  2.8
# 42   29.0     12.0  ...       0  BachDegree  20to49k  4.4  4.25  1.6  2.8
# 43   29.0     12.0  ...       0  BachDegree  20to49k  4.4  4.25  1.6  2.8
# 44   29.0     13.0  ...       0  BachDegree  20to49k  4.4  4.25  1.6  2.8
# 45   29.0     14.0  ...       0  BachDegree  20to49k  4.4  4.25  1.6  2.8
# 46   29.0     15.0  ...       0  BachDegree  20to49k  4.4  4.25  1.6  2.8
# 47   29.0     16.0  ...       0  BachDegree  20to49k  4.4  4.25  1.6  2.8
# 48   32.0     17.0  ...       0  BachDegree  20to49k  4.4  4.25  1.6  2.8
# 49   32.0     17.0  ...       0  BachDegree  20to49k  4.4  4.25  1.6  2.8
#
#      TS  Regularity  Reinforcement
# 0   2.0    2.095558      50.086906
# 1   2.0    2.095558      50.086906
# 2   2.0    2.095558      50.086906
# 3   2.0    2.095558      50.086906
# 4   2.0    2.095558      50.086906
# 5   2.0    2.095558      50.086906
# 6   2.0    2.095558      50.086906
# 7   2.0    2.095558      50.086906
# 8   2.0    2.095558      50.086906
# 9   2.0    2.095558      50.086906
# 10  2.0    2.095558      50.086906
# 11  2.0    2.095558      50.086906
# 12  2.0    2.095558      50.086906
# 13  2.0    2.095558      50.086906
# 14  2.0    2.095558      50.086906
# 15  2.0    2.095558      50.086906
# 16  2.0    2.095558      50.086906
# 17  2.0    2.095558      50.086906
# 18  2.0    2.095558      50.086906
# 19  2.0    2.095558      50.086906
# 20  2.0    2.095558      50.086906
# 21  2.0    2.095558      50.086906
# 22  2.0    2.095558      50.086906
# 23  2.0    2.095558      50.086906
# 24  2.0    2.095558      50.086906
# 25  2.0    2.095558      50.086906
# 26  2.0    2.095558      50.086906
# 27  2.0    2.095558      50.086906
# 28  2.0    2.095558      50.086906
# 29  2.0    2.095558      50.086906
# 30  2.0    2.095558      50.086906
# 31  2.0    2.095558      50.086906
# 32  2.0    2.095558      50.086906
# 33  2.0    2.095558      50.086906
# 34  2.0    2.095558      50.086906
# 35  2.0    2.095558      50.086906
# 36  2.0    2.095558      50.086906
# 37  2.0    2.095558      50.086906
# 38  2.0    2.095558      50.086906
# 39  2.0    2.095558      50.086906
# 40  2.0    2.095558      50.086906
# 41  2.0    2.095558      50.086906
# 42  2.0    2.095558      50.086906
# 43  2.0    2.095558      50.086906
# 44  2.0    2.095558      50.086906
# 45  2.0    2.095558      50.086906
# 46  2.0    2.095558      50.086906
# 47  2.0    2.095558      50.086906
# 48  2.0    2.095558      50.086906
# 49  2.0    2.095558      50.086906
#
# [50 rows x 25 columns]

# %%
df.to_csv('/Volumes/My Passport/Curiosity/v8/Data/KNOT/processed_KNOT_data.csv', index = False)

# %%
df_2 = pd.DataFrame(columns = ['ID', 'density', 'num_nodes', 'num_edges', 'num_change_points', 
                             'Age', 'Sex', 'Race', 'Gender', 'Education', 'Income',
                             'JE', 'DS', 'ST', 'SC', 'TS',
                             'Regularity', 'Reinforcement'
                              ])
for i, subj_ID in enumerate(np.squeeze(ID).tolist()):
    print('Processing subject %d.' % subj_ID)
    df_2 = df_2.append({'ID': int(subj_ID),  
                    'density': density[i][0], 
                    'num_nodes': num_nodes[i][0], 
                    'num_edges': num_edges[i][0], 
                    'num_change_points': num_change_points[i][0],
                    'Age': KNOT_all_raw.loc[KNOT_all_raw['ID'] == subj_ID, 'AgeYears'].iloc[0],
                    'Sex': KNOT_all_raw.loc[KNOT_all_raw['ID'] == subj_ID, 'SexOrient'].iloc[0],
                    'Race': KNOT_all_raw.loc[KNOT_all_raw['ID'] == subj_ID, 'Race'].iloc[0],
                    'Gender': KNOT_all_raw.loc[KNOT_all_raw['ID'] == subj_ID, 'GenderFactor'].iloc[0],
                    'Education': KNOT_all_raw.loc[KNOT_all_raw['ID'] == subj_ID, 'EducDeg'].iloc[0],
                    'Income': KNOT_all_raw.loc[KNOT_all_raw['ID'] == subj_ID, 'Income'].iloc[0],
                    'JE': KNOT_all_raw.loc[KNOT_all_raw['ID'] == subj_ID, 'JE_5D'].iloc[0],
                    'DS': KNOT_all_raw.loc[KNOT_all_raw['ID'] == subj_ID, 'DS_5D'].iloc[0],
                    'ST': KNOT_all_raw.loc[KNOT_all_raw['ID'] == subj_ID, 'ST_5D'].iloc[0],
                    'SC': KNOT_all_raw.loc[KNOT_all_raw['ID'] == subj_ID, 'SC_5D'].iloc[0],
                    'TS': KNOT_all_raw.loc[KNOT_all_raw['ID'] == subj_ID, 'TS_5D'].iloc[0],
                    'Regularity': reinf_reg.loc[reinf_reg['ID'] == subj_ID, 'Regularity'].item(),
                    'Reinforcement': reinf_reg.loc[reinf_reg['ID'] == subj_ID, 'Reinforcement'].item()
                   }, ignore_index = True)
# Out:
# Processing subject 101.
# Processing subject 104.
# Processing subject 105.
# Processing subject 106.
# Processing subject 107.
# Processing subject 108.
# Processing subject 109.
# Processing subject 112.
# Processing subject 114.
# Processing subject 115.
# Processing subject 117.
# Processing subject 119.
# Processing subject 120.
# Processing subject 121.
# Processing subject 122.
# Processing subject 126.
# Processing subject 127.
# Processing subject 128.
# Processing subject 130.
# Processing subject 131.
# Processing subject 132.
# Processing subject 135.
# Processing subject 138.
# Processing subject 139.
# Processing subject 140.
# Processing subject 141.
# Processing subject 146.
# Processing subject 150.
# Processing subject 153.
# Processing subject 154.
# Processing subject 155.
# Processing subject 156.
# Processing subject 157.
# Processing subject 158.
# Processing subject 159.
# Processing subject 162.
# Processing subject 164.
# Processing subject 165.
# Processing subject 167.
# Processing subject 169.
# Processing subject 171.
# Processing subject 173.
# Processing subject 174.
# Processing subject 176.
# Processing subject 177.
# Processing subject 179.
# Processing subject 183.
# Processing subject 185.
# Processing subject 188.
# Processing subject 189.
# Processing subject 190.
# Processing subject 191.
# Processing subject 192.
# Processing subject 194.
# Processing subject 196.
# Processing subject 197.
# Processing subject 198.
# Processing subject 199.
# Processing subject 201.
# Processing subject 204.
# Processing subject 206.
# Processing subject 207.
# Processing subject 208.
# Processing subject 209.
# Processing subject 210.
# Processing subject 211.
# Processing subject 212.
# Processing subject 214.
# Processing subject 216.
# Processing subject 217.
# Processing subject 219.
# Processing subject 220.
# Processing subject 221.
# Processing subject 223.
# Processing subject 224.
# Processing subject 225.
# Processing subject 226.
# Processing subject 228.
# Processing subject 229.
# Processing subject 231.
# Processing subject 232.
# Processing subject 234.
# Processing subject 235.
# Processing subject 236.
# Processing subject 238.
# Processing subject 239.
# Processing subject 240.
# Processing subject 242.
# Processing subject 243.
# Processing subject 246.
# Processing subject 247.
# Processing subject 248.
# Processing subject 249.
# Processing subject 251.
# Processing subject 253.
# Processing subject 255.
# Processing subject 256.
# Processing subject 258.
# Processing subject 259.
# Processing subject 261.
# Processing subject 263.
# Processing subject 264.
# Processing subject 266.
# Processing subject 267.
# Processing subject 268.
# Processing subject 269.
# Processing subject 271.
# Processing subject 273.
# Processing subject 278.
# Processing subject 280.
# Processing subject 286.
# Processing subject 287.
# Processing subject 288.
# Processing subject 290.
# Processing subject 291.
# Processing subject 293.
# Processing subject 296.
# Processing subject 297.
# Processing subject 304.
# Processing subject 308.
# Processing subject 309.
# Processing subject 310.
# Processing subject 311.
# Processing subject 312.
# Processing subject 313.
# Processing subject 316.
# Processing subject 318.
# Processing subject 319.
# Processing subject 321.
# Processing subject 322.
# Processing subject 323.
# Processing subject 324.
# Processing subject 325.
# Processing subject 327.
# Processing subject 328.
# Processing subject 329.
# Processing subject 335.
# Processing subject 338.
# Processing subject 339.
# Processing subject 340340.
# Processing subject 340.
# Processing subject 342.
# Processing subject 349.
# Processing subject 351.
# Processing subject 353.
# Processing subject 355.
# Processing subject 356.
# Processing subject 359.
# Processing subject 363.

# %%
df_2.head(50)
# Out:
#      ID   density num_nodes num_edges num_change_points        Age  \
# 0   101  0.010650       285       431                 1  23.279450
# 1   104  0.021935       125       170                 1  30.843840
# 2   105  0.024383        84        85                 1  31.268490
# 3   106  0.012459       317       624                 2  25.994520
# 4   107  0.012026       174       181                 1  65.235620
# 5   108  0.015725       111        96                 1  51.580820
# 6   109  0.010873       109        64                 1  30.024660
# 7   112  0.034953        69        82                 3  34.219180
# 8   114  0.023256        86        85                 1  20.457530
# 9   115  0.015787       289       657                 2  22.402740
# 10  117  0.016387       120       117                 1  26.997260
# 11  119  0.011131       224       278                 1  36.219180
# 12  120  0.027656       105       151                 1  27.479452
# 13  121  0.006093       268       218                 1  24.561644
# 14  122  0.013595       202       276                 1  34.871233
# 15  126  0.023191       186       399                 2  29.106850
# 16  127  0.015223       167       211                 1  24.452050
# 17  128  0.027693       109       163                 1  27.180820
# 18  130  0.011491       257       378                 1  30.482190
# 19  131  0.014133       244       419                 1  26.123288
# 20  132  0.021131       103       111                 1  22.805480
# 21  135  0.026302       183       438                 2  25.545210
# 22  138  0.009847       199       194                 1  24.578080
# 23  139  0.018820       173       280                 1  38.369860
# 24  140  0.015174       122       112                 1        NaN
# 25  141  0.008800       367       591                 2  26.032880
# 26  146  0.014813       119       104                 1  26.643840
# 27  150  0.028571        56        44                 1  28.389040
# 28  153  0.008308       368       561                 1  20.389040
# 29  154  0.023651       165       320                 2  22.128770
# 30  155  0.014435       226       367                 1  22.216440
# 31  156  0.031100        74        84                 1  22.975340
# 32  157  0.014571       185       248                 1  20.769860
# 33  158  0.016886        96        77                 1  25.709590
# 34  159  0.014308       211       317                 1  24.635620
# 35  162  0.020729       122       153                 1  25.345210
# 36  164  0.010228       229       267                 1  26.060270
# 37  165  0.063973        55        95                 2  21.016440
# 38  167  0.028919        73        76                 2  18.213700
# 39  169  0.016920       271       619                 2  19.000000
# 40  171  0.086154        26        28                 1  25.087670
# 41  173  0.035562        38        25                 2  37.490410
# 42  174  0.023083        72        59                 1  39.778080
# 43  176  0.038596        76       110                 1  49.947950
# 44  177  0.018965        99        92                 1  25.112330
# 45  179  0.035017        55        52                 1  18.972600
# 46  183  0.008745       254       281                 1  21.717810
# 47  185  0.016848       228       436                 2  19.994520
# 48  188  0.016649       215       383                 2  21.208220
# 49  189  0.038577        86       141                 1  19.536990
#
#              Sex    Race Gender            Education             Income   JE  \
# 0   Heterosexual  AsiaAm      0           BachDegree            20to49k  4.4
# 1   Heterosexual   White      0           BachDegree           under20k  3.2
# 2   Heterosexual   White      0               Master          150to199k  3.0
# 3   Heterosexual  AsiaAm      0           BachDegree          100to149k  5.6
# 4   Heterosexual   White      0               Master            50to74k  3.4
# 5   Heterosexual   White      0               Master          150to199k  4.8
# 6   Heterosexual   White      0           BachDegree            50to74k  2.8
# 7   Heterosexual   White      1               Master            50to74k  4.4
# 8   Heterosexual  AsiaAm      0  SomeCollegeNoDegree           200andup  4.4
# 9   Heterosexual  AsiaAm      0           BachDegree  PreferNotToAnswer  3.8
# 10  Heterosexual   White      0           BachDegree          100to149k  3.8
# 11  Heterosexual   White      0               Master            20to49k  4.2
# 12         Other   White      0               Master           under20k  4.4
# 13           Gay   White      1           BachDegree            50to74k  3.8
# 14  Heterosexual   White      0               Master          100to149k  5.8
# 15  Heterosexual  AsiaAm      0     ProfSchoolDegree            50to74k  5.2
# 16  Heterosexual   White      0           BachDegree          150to199k  4.2
# 17  Heterosexual  AsiaAm      0           BachDegree            20to49k  3.8
# 18         Other   White      0      AssociateDegree            20to49k  3.4
# 19  Heterosexual   White      0           BachDegree  PreferNotToAnswer  3.8
# 20  Heterosexual   White      0           BachDegree            50to74k  5.4
# 21      Bisexual   Mixed      0           BachDegree           200andup  2.0
# 22  Heterosexual   Other      1               Master            20to49k  5.2
# 23         Other   White      0           BachDegree            50to74k  4.6
# 24  Heterosexual   White      0           BachDegree                NaN  4.8
# 25  Heterosexual   White      0           BachDegree           under20k  1.2
# 26  Heterosexual  AsiaAm      0           BachDegree          100to149k  3.2
# 27  Heterosexual   White      0               Master            75to99k  6.0
# 28  Heterosexual   White      0  SomeCollegeNoDegree  PreferNotToAnswer  3.2
# 29  Heterosexual  AsiaAm      0  SomeCollegeNoDegree  PreferNotToAnswer  5.2
# 30  Heterosexual  AsiaAm      0       HighSchoolGrad  PreferNotToAnswer  5.4
# 31  Heterosexual  AsiaAm      0           BachDegree          100to149k  4.0
# 32  Heterosexual   White      0  SomeCollegeNoDegree            50to74k  5.4
# 33      Bisexual   White      0               Master            20to49k  5.2
# 34      Bisexual   White      0           BachDegree  PreferNotToAnswer  5.2
# 35  Heterosexual   White      0           BachDegree  PreferNotToAnswer  3.4
# 36  Heterosexual   Other      0               Master            20to49k  5.2
# 37  Heterosexual   Mixed      0  SomeCollegeNoDegree          100to149k  5.6
# 38  Heterosexual   White      1  SomeCollegeNoDegree           200andup  5.6
# 39  Heterosexual   Other      0       HighSchoolGrad          100to149k  5.8
# 40  Heterosexual   Other      0               Master            75to99k  5.8
# 41  Heterosexual   White      1               Master            75to99k  4.8
# 42  Heterosexual   AfrAm      0           BachDegree            50to74k  6.0
# 43  Heterosexual   Other      0      AssociateDegree  PreferNotToAnswer  4.8
# 44  Heterosexual   Mixed      0           BachDegree            20to49k  2.4
# 45  Heterosexual  AsiaAm      0  SomeCollegeNoDegree           200andup  5.0
# 46         Other  AsiaAm      0  SomeCollegeNoDegree            20to49k  4.2
# 47  Heterosexual   White      0  SomeCollegeNoDegree          150to199k  4.6
# 48  Heterosexual   White      1           BachDegree           200andup  5.2
# 49  Heterosexual   White      0       HighSchoolGrad          150to199k  4.2
#
#       DS   ST   SC    TS  Regularity  Reinforcement
# 0   4.25  1.6  2.8  2.00    2.095558      50.086906
# 1   2.50  2.4  4.0  0.00    1.871805      36.527710
# 2   3.00  3.0  2.4  1.00    1.932047      39.451567
# 3   3.50  1.4  5.2  1.25    2.089505      46.694123
# 4   2.75  2.5  2.4  0.75    2.308878      36.949026
# 5   5.00  3.0  4.8  4.50    2.073689      36.680929
# 6   3.75  0.4  1.6  1.75    2.090140      42.432988
# 7   2.00  1.2  3.4  3.00    2.088085      33.653904
# 8   4.50  4.0  4.6  4.00    1.870814      47.644795
# 9   4.00  3.6  4.0  3.60    2.385505      42.245600
# 10  1.40  3.2  5.4  4.20    2.369347      36.596519
# 11  4.20  1.2  5.0  2.40    2.118561      40.761544
# 12  4.60  3.2  2.4  2.80    2.090799      38.416381
# 13  3.20  2.6  4.4  3.00    2.425926      30.528659
# 14  4.20  1.0  4.4  4.80    2.234964      36.568041
# 15  4.00  1.6  2.2  3.80    2.046520      31.125549
# 16  4.00  2.0  4.2  2.00    2.316657      32.590601
# 17  4.00  0.8  5.2  4.60    2.044756      35.032222
# 18  1.60  1.6  2.6  1.60    2.229078      27.006731
# 19  3.40  3.4  5.6  1.60    2.272852      46.593828
# 20  5.00  0.8  5.4  4.80    2.032234      40.958526
# 21  3.20  5.0  2.6  0.60    2.074844      46.765997
# 22  3.40  0.8  2.2  1.60    1.928459      26.849185
# 23  4.60  3.4  3.6  2.40    1.865780      37.759536
# 24  5.40  1.8  4.2  3.20    2.402822      44.066912
# 25  3.60  3.4  4.2  0.20    2.169257      48.101930
# 26  3.60  2.8  3.8  3.60    2.108026      50.181856
# 27  4.80  2.0  5.6  2.00    2.248798      26.559594
# 28  2.80  3.4  4.2  1.40    2.059999      48.970468
# 29  4.80  1.0  5.0  3.00    2.360013      36.388509
# 30  5.00  1.8  6.0  4.60    2.320735      47.264607
# 31  5.00  2.2  3.2  1.40    2.051554      42.827067
# 32  3.80  0.8  5.8  4.60    2.171538      38.156793
# 33  5.40  1.0  6.0  3.20    2.222750      43.727284
# 34  4.00  4.0  4.8  0.80    2.162539      37.946588
# 35  4.20  2.2  4.2  1.40    2.198290      46.739167
# 36  2.20  2.2  5.8  4.00    2.224864      42.621113
# 37  5.60  3.8  5.2  5.60    2.033913      29.061748
# 38  3.60  1.6  5.8  5.00    2.252287      39.893345
# 39  4.00  1.8  3.8  2.00    1.846698      39.224709
# 40  5.00  2.2  4.4  2.60    1.882539      42.212624
# 41  3.60  0.4  5.2  3.00    2.057533      34.700906
# 42  5.00  0.2  5.4  3.75    2.281058      46.935510
# 43  3.80  2.6  2.6  2.40    2.090350      43.205561
# 44  1.00  2.8  5.8  1.60    1.995383      45.632227
# 45  4.60  2.0  5.2  3.00    2.230978      50.706397
# 46  4.00  4.2  4.4  1.20    2.462113      37.392574
# 47  4.20  0.8  5.0  4.80    1.990278      43.963208
# 48  5.00  2.6  5.4  3.40    2.228746      40.053323
# 49  3.20  1.0  3.4  0.80    2.404848      38.796856

# %%
df_2.to_csv('/Volumes/My Passport/Curiosity/v8/Data/KNOT/processed_KNOT_data_no_curves.csv', index = False)
